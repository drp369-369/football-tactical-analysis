# %%
# GenAI Tactical Match Explainer

This notebook demonstrates how generative AI can translate
football analytics metrics into coach-ready tactical insights.

# %%
## Context

In professional football, large volumes of analytical data are often difficult
to communicate effectively to coaching staff. This notebook illustrates how
generative AI can act as an interpretation layer, transforming analytical outputs
into tactical insights that support decision-making.

# %%
import json

with open("/content/sample_metrics.json", "r") as f:
    metrics = json.load(f)

metrics

# %%
with open("/content/tactical_prompt.txt", "r") as f:
    system_prompt = f.read()

full_prompt = system_prompt + "\n\nMatch Metrics:\n" + json.dumps(metrics, indent=2)
full_prompt

# %%
generated_report = """
France adopted a compact central structure, prioritizing controlled possession
and selective progression through the right half-space. Midfield hubs such as
Pogba and Kanté facilitated circulation and tempo control, reducing transition risk.

This structure allowed France to manage the match rhythm while maintaining
defensive stability, suggesting a pragmatic approach focused on efficiency.
"""
print(generated_report)

# %%
## Conclusion

This prototype highlights the potential of generative AI to enhance the
interpretation and communication of football analytics. By focusing on clarity
and tactical relevance, such systems can support analysts and coaches in
understanding game dynamics more efficiently.
